# %% [markdown]
# # 딥러닝
# 딥러닝은 인공 지능(AI)의 한 분야로, 데이터에서 복잡한 패턴을 학습하는 데 중점을 둔 기계 학습의 한 형태입니다. 이는 인간의 뇌가 정보를 처리하고 학습하는 방식을 모방한 인공 신경망을 사용합니다. 딥러닝 모델은 여러 층(layer)을 통해 데이터를 처리하며, 각 층은 데이터에서 점점 더 추상적이고 복잡한 특징을 추출하고 학습하는 역할을 합니다.

# %% [markdown]
# ## 활성화 함수
# 활성화 함수는 인공 신경망의 기본 구성 요소 중 하나로, 뉴런이나 노드로 들어오는 입력 신호의 가중합을 출력 신호로 변환하는 비선형 함수입니다. 이 함수는 신경망 내에서 다음 레이어로의 신호 전달 여부와 강도를 결정합니다. 활성화 함수 없이 신경망은 단순한 선형 회귀 모델과 다르지 않게 되며, 복잡한 문제를 해결하거나 데이터의 비선형 패턴을 학습할 수 없게 됩니다. 활성화 함수는 비선형성을 도입함으로써 신경망이 더 깊고 복잡한 구조를 가질 수 있게 하며, 실제 세계의 데이터를 더 잘 모델링할 수 있도록 합니다. 다양한 활성화 함수가 있으며, 각각의 특성과 용도에 따라 선택됩니다.
#
# ### 1. 계단 함수
# 계단 함수(Step Function)는 가장 기본적인 형태의 활성화 함수 중 하나로, 입력 값에 따라 두 가지 값(예: 0 또는 1)만을 출력합니다. 이 함수는 입력이 특정 임계값(threshold)보다 작거나 같을 때 하나의 값(예: 0)을, 임계값을 초과할 때 다른 값(예: 1)을 출력합니다. 계단 함수는 비선형 함수로 분류되며, 인공 신경망에서 이진 분류 문제를 해결하는 데 초기에 사용되었습니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 딥러닝 원리 및 구현
# 공부시간 + 문제집 푼 개수 => 성적예측
# --> a1*t1 + a2*t2 + b = 성적

# 딥러닝원리(경사하강법) : 계속되는 미분 + 구현

# %%
def step_function(x):
    y = x > 0
    return y.astype(np.int32)

# %%
x = np.array([-1, 1, 2])
step_function(x)
# Out:
# array([0, 1, 1], dtype=int32)

# %%
x = np.arange(-5, 5, 0.1)
y = step_function(x)
plt.plot(x, y)

# %% [markdown]
# ### 2. 시그모이드 함수
# 시그모이드 함수(Sigmoid Function)는 인공 신경망에서 널리 사용되는 활성화 함수 중 하나로, 주로 이진 분류 문제에서 출력층의 활성화 함수로 사용됩니다. 이 함수는 입력값을 받아 0과 1 사이의 값으로 출력하며, 이는 확률로 해석될 수 있습니다. 시그모이드 함수는 S자 형태의 곡선을 그리며, 이로 인해 로지스틱 함수(Logistic Function)라고도 불립니다.

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
x = np.arange(-5, 5, 0.1)
plt.plot(sigmoid(x))

# %% [markdown]
# ### 3.ReLU 함수
# ReLU(Rectified Linear Unit) 함수는 인공 신경망에서 가장 널리 사용되는 활성화 함수 중 하나입니다. 이 함수는 간단하면서도 효율적인 비선형 함수로, 입력이 0보다 크면 그 입력을 그대로 출력하고, 0 이하면 0을 출력합니다.

# %%
def relu(x):
    return np.maximum(0, x)

# %%
x = np.arange(-5, 5, 0.1)
plt.plot(relu(x))

# %% [markdown]
# ## 다차원 배열 계산
# 다차원 배열이란, 수학에서의 행렬 개념을 확장한 것으로, 2차원 이상의 데이터를 포함할 수 있는 배열을 말합니다. 다차원 배열을 사용하면 복잡한 데이터 세트를 효율적으로 조작하고 분석할 수 있습니다.

# %%
# 분류 : 길이,무게 -> 도미,방어
A = np.random.randn(2,2) #랜덤한 값을 가지는 2행 2열 행렬 생성
B = np.random.randn(2,2) #랜덤한 값을 가지는 2행 2열 행렬 생성
np.dot(A,B) # A와 B 행렬곱을 함
# Out:
# array([[ 2.61332855, -1.91095934],
#        [ 1.96077945, -1.46419627]])

# %%
A = np.random.randn(2, 3)
B = np.random.randn(3, 2)
np.dot(A,B)
# Out:
# array([[ 1.89234247,  1.33837702],
#        [-0.76491073, -1.26437819]])

# %%
A = np.random.rand(3, 2) # 3행 2열 => 2차원 행렬 
A.shape # (3,2)로 출력
B = np.random.rand(2) # 1행 2열 => 1차원 행렬
B.shape # (2,) 로 출력
np.dot(A,B)
# Out:
# array([0.03374807, 0.02535705, 0.02715665])

# %% [markdown]
# ### 1. 신경망에서의 행렬 곱
# 신경망에서의 행렬 곱(또는 행렬 곱셈)은 신경망의 핵심 연산 중 하나로, 입력 데이터와 가중치 사이의 선형 변환을 수행하는 과정입니다. 이 연산을 통해 네트워크는 데이터의 특성을 학습할 수 있게 됩니다. 신경망의 각 레이어에서 발생하는 행렬 곱은 다음 레이어로 전달되는 입력 데이터를 생성하며, 이 과정은 네트워크의 깊이에 따라 반복됩니다.

# %%
X = np.array([2,1]) #공부시간, 문제집푼개수
W = np.random.randn(2, 3) # 2행 3열의 은닉층을 생성
B = np.random.randn(3) # Bias, 단순 1차원을 만듦

A1 = np.dot(X, W) + B
Z1 = sigmoid(A1)

# %% [markdown]
# ### 2. 3층 신경망 구현하기
# 이를 위해 앞에서 설명한 다차원 배열을 사용합니다. 넘파이 배열을 잘 활용하면 아주 적은 코드만으로 신경망의 순방향 처리를 완성할 수 있습니다.

# %%
X = np.array([2,1]) #공부시간, 문제집푼개수
W1 = np.random.randn(2, 3) # 2행 3열의 은닉층을 생성
B1 = np.random.randn(3) # Bias, 단순 1차원을 만듦

A1 = np.dot(X, W1) + B
Z1 = sigmoid(A1)

W2 = np.random.randn(3,2)
B2 = np.random.rand(2)

A2 = np.dot(Z1,W2) + B2
Z2 = sigmoid(A2)
Z2
# Out:
# array([0.41935775, 0.41618078])

# %% [markdown]
# ### 3. 3층 신경망 정리
# 위에서 정리한 3층 신경망 구현을 함수로 정리하면 계속해서 쉽게 사용할 수 있습니다.

# %%
import numpy as np

def sigmoid(x):
    """Sigmoid 활성화 함수."""
    return 1 / (1 + np.exp(-x))

def initialize_network(input_size, hidden_size, output_size):
    """신경망의 가중치와 편향을 초기화합니다."""
    W1 = np.random.randn(input_size, hidden_size)
    B1 = np.random.randn(hidden_size)
    W2 = np.random.randn(hidden_size, output_size)
    B2 = np.random.randn(output_size)
    return W1, B1, W2, B2

def forward_pass(X, W1, B1, W2, B2):
    """신경망의 순전파 단계를 계산합니다."""
    # 첫 번째 층의 계산
    A1 = np.dot(X, W1) + B1
    Z1 = sigmoid(A1)   
    # 두 번째 층 (출력층)의 계산
    A2 = np.dot(Z1, W2) + B2
    Z2 = sigmoid(A2)
    return Z2

def run_network():
    """신경망을 실행합니다."""
    X = np.array([2, 1])  # 입력 벡터
    input_size = 2
    hidden_size = 3
    output_size = 2
    
    # 네트워크 초기화
    W1, B1, W2, B2 = initialize_network(input_size, hidden_size, output_size)
    # 순전파 실행
    output = forward_pass(X, W1, B1, W2, B2)
    return output

output = run_network()
print("Output of the neural network is:", output)
# Out:
# Output of the neural network is: [0.79171452 0.22342753]

# %% [markdown]
# ## 소프트맥스 함수
# 소프트맥스 함수(Softmax Function)는 다중 클래스 분류 문제에서 사용되는 활성화 함수입니다. 이 함수는 신경망의 마지막 레이어에서 주로 사용되며, 각 클래스에 대한 예측의 확률 분포를 출력합니다. 소프트맥스 함수는 입력된 벡터의 각 요소를 0과 1 사이의 값으로 변환하고, 모든 출력 값의 합이 1이 되도록 합니다. 이로 인해 각 요소는 특정 클래스에 속할 확률로 해석될 수 있습니다.

# %%
def softmax(x):
    # x에서 최대값을 빼서 수치적 안정성을 확보
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

x = np.arange(-5, 5, 0.1)
plt.plot(softmax(x))

# %%
a = np.array([0.3, 2.9, 4])
softmax(a)
# Out:
# array([0.01821127, 0.24519181, 0.73659691])

# %%
a = np.array([1010, 1000, 990])
c = np.max(a)
exp_ap = np.exp(a-c)
sum_exp_a = np.sum(exp_a)
exp_a / sum_exp_a

# %%
a = np.array([[0.3, 2.9, 4], [3.3, 2.9, 1]])
c = np.max(a, axis=1).reshape(-1,1) #자동행, 1열로 만들어라
exp_a = np.exp(a-c)
sum_exp_a = np.sum(exp_a, axis=1).reshape(-1, 1)
y = exp_a / sum_exp_a

### 여기에 맞게...
def softmax_2(a):
    c = np.max(a, axis=1).reshape(-1,1) #자동행, 1열로 만들어라
    exp_a = np.exp(a-c)
    sum_exp_a = np.sum(exp_a, axis=1).reshape(-1, 1)
    return exp_a / sum_exp_a

# %%
a = np.array([[0.3, 2.9, 4]])
softmax_2(a)
# Out:
# array([[0.01821127, 0.24519181, 0.73659691]])

# %% [markdown]
# ## MNIST 손글씨 숫자 인식
# MNIST 숫자 데이터셋은 손으로 쓴 숫자(0부터 9까지)의 대규모 데이터베이스로, 기계 학습 분야에서 광범위하게 사용되는 벤치마크 데이터셋 중 하나입니다. MNIST는 "Modified National Institute of Standards and Technology"의 약자로, 원래 NIST의 데이터셋을 더 사용하기 쉽게 변형한 것입니다.
# * 데이터셋은 60,000개의 훈련 이미지와 10,000개의 테스트 이미지로 구성되어 있습니다. 각 이미지는 28x28 픽셀의 크기를 가지며, 흑백(grayscale)으로 되어 있습니다.

# %%
# ChatGPT가 짜준 것
# !pip3 install tensorflow --timeout=1000
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# 데이터셋을 불러오고 훈련/테스트 세트로 나눕니다.
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),  # 28x28 이미지를 1D 벡터로 변환
    tf.keras.layers.Dense(128, activation='relu'),  # 128개의 노드를 가진 은닉층
    tf.keras.layers.Dropout(0.2),  # 과적합 방지를 위한 드롭아웃
    tf.keras.layers.Dense(10, activation='softmax')  # 10개의 출력 노드, 각 숫자의 확률 출력
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size = 64)
# 모델 훈련 부분에서 batch_size=64를 설정함으로써, 60000개의 훈련 샘플을 64개씩의 배치로 나누어 훈련시킵니다. 이는 한 번에 64개의 이미지만 메모리에 로드되어 처리된다는 의미입니다.

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest accuracy:', test_acc)

# %%
# 강사 방법

from tensorflow import keras
(train_x, train_y), (test_x, test_y) = keras.datasets.mnist.load_data()

plt.imshow(train_x[0], cmap='gray')
plt.show()

train_scaled = train_x.reshape(60000, 784) / 255 # 0~1 : MinMaxScalar
test_scaled = test_x.reshape(10000, 784) / 255 # 0~1 : MinMaxScalar

a = train_scaled[0] # 5번 그림
a.shape
# Out:
# (784,)

# %%
## weight 값 로드 및 적용
import pickle
f = open("sample_weight.pkl", "rb") # 가중치값 로드
net = pickle.load(f)
f.close()

W1, W2, W3 = net['W1'], net['W2'], net['W3']
b1, b2, b3 = net['b1'], net['b2'], net['b3']

A1 = np.dot(a,W1) + b1 # 은닉 1층 계산
Z1 = sigmoid(A1) #시그모이드 계산(학습)

A2 = np.dot(Z1, W2) + b2 # 은닉 2층 계산
Z2 = sigmoid(A2) #시그모이드 계산(학습)

A3 = np.dot(Z2, W3) + b3 # 출력값 계산
y = softmax(A3) # 0~1사이 소프트맥스 계산
np.argmax(y) # 결과는? a의 숫자는 무엇인가?!
# Out:
# 5

# %%
# 예측을 하는 함수를 아예 정의
def predict(net, a):
    W1, W2, W3 = net['W1'], net['W2'], net['W3']
    b1, b2, b3 = net['b1'], net['b2'], net['b3']
    
    A1 = np.dot(a,W1) + b1 # 은닉 1층 계산
    Z1 = sigmoid(A1) #시그모이드 계산(학습)

    A2 = np.dot(Z1, W2) + b2 # 은닉 2층 계산
    Z2 = sigmoid(A2) #시그모이드 계산(학습)

    A3 = np.dot(Z2, W3) + b3 # 출력값 계산
    y = softmax(A3) # 0~1사이 소프트맥스 계산

    return y


count = 0
for i in range(len(test_scaled)):
    pre_result = predict(net, test_scaled[i]) #predict 함수에 맞게 각 test 내용들을 sigmoid/sigmoid/softmax계산
    result = np.argmax(pre_result) #각 계산결과를 np.argmax로 예측적용
    if result == test_y[i]:
        count += 1

print(count / len(test_y) * 100, end="")
print("% 만큼의 정확도를 가짐")
# Out:
# 93.52000000000001% 만큼의 정확도를 가짐

# %% [markdown]
# ### 1. 배치 처리
# 딥러닝에서 배치 처리(batch processing)는 모델 학습 시 데이터를 작은 그룹, 즉 "배치(batch)"로 나누어 처리하는 기법을 말합니다. 각 배치에는 여러 개의 샘플이 포함되며, 이러한 방식으로 데이터셋 전체가 네트워크를 통해 순차적으로 전달됩니다. 배치 처리는 계산 효율성을 높이고 메모리 사용을 최적화하는 데 도움을 줍니다.

# %%
x = np.array([[0.1, 0.8, 0.1], 
              [0.3, 0.1, 0.6], 
              [0.2, 0.5, 0.3], 
              [0.8, 0.1, 0.1]])
y = np.argmax(x, axis = 1)

##############
y = np.array([1,2,1,0]) # 예측값
t = np.array([1,2,0,0]) # 실제값
sum(y==t) # 몇개 맞췄는지
# Out:
# 3

# %%
batch_size = 100
count = 0 
for i in range(0, len(test_y), batch_size):
    batch_x = test_scaled[i : i+batch_size]
    batch_y = predict(net, batch_x)
    p = np.argmax(batch_y, axis=1)
    count += sum(p == test_y[i : i+batch_size])
count / len(test_y) * 100
# Out:
# 92.07

# %% [markdown]
# ## 신경망에서의 기울기
# 신경망에서의 기울기는 네트워크의 가중치와 편향에 대한 손실 함수의 변화율을 나타내는 벡터입니다. 신경망을 학습시키는 과정에서는 손실 함수의 값을 최소화하기 위해 가중치와 편향을 조절해야 합니다. 이 때, 손실 함수의 기울기를 사용하여 네트워크의 가중치와 편향을 어떻게 조정해야 하는지 결정합니다.

# %% [markdown]
# ### 1. 크로스 엔트로피 오차
# 교차 엔트로피 오차(Cross Entropy Error)는 분류 문제에서 널리 사용되는 손실 함수의 한 종류입니다. 신경망이 분류 문제를 해결할 때, 실제 값과 예측 값 사이의 차이를 나타내기 위해 교차 엔트로피 오차를 사용합니다. 이 손실 함수는 실제로 관찰된 레이블과 모델에 의해 예측된 확률 분포 사이의 불일치를 측정합니다.

# %%
y = np.array([0.1, 0.5, 0.4]) #예측값
t = np.array([0, 1, 0]) #실제값

#크로스 엔트로피 오차의 공식
-np.sum(np.log(y) * t) #로그함수로 변환 후 이를 실제값과 서로 곱해 합한 값의 마이너스(-) == 크로스 엔트로피 오차 계산)
# Out:
# 0.6931471805599453

# %%
y = np.array([[0.1, 0.8, 0.1], 
              [0.3, 0.1, 0.6], 
              [0.2, 0.5, 0.3], 
              [0.8, 0.1, 0.1]]) #예측값
t = np.array([1, 2, 1, 0]) #실제값

-np.sum(y[np.arange(len(y)), t])
#-np.sum(np.log(y) * t) #로그함수로 변환 후 이를 실제값과 서로 곱해 합한 값의 마이너스(-) == 크로스 엔트로피 오차 계산)
# Out:
# -2.7

# %%
def cross_entropy_error(y, t):
    # 배열이 1차원인 경우, 배치 크기가 1인 2차원 배열로 ㅂㅕㄴ형
    if y.ndim == 1:
        t = t.reshape(-1, t.size)
        y = y.reshape(-1, y.size)
    batch_size = y.shape[0]

    # 아주 작은 값을 더하여 log(0)이 무한대가 되는 것을 방지
    delta = 1e-7
    return -np.sum(t * np.log(y + delta)) / y.shape[0]

class SimpleNet:
    def __init__(self):
        self.W = np.random.randn(2, 3) #2행3열짜리 랜덤행렬 생성
        
    def predict(self, x):
        return np.dot(x, self.W)
    
    def loss(self, x, t):
        z = self.predict(x)
        y = softmax(z)
        loss = cross_entropy_error(y, t)
        return loss

# %%
# 예제 사용
net = SimpleNet()
x = np.array([0.6, 0.9])  # 입력 데이터
t = np.array([0, 0, 1])  # 정답 레이블(원-핫 인코딩)

# 예측 및 손실 계산
pred = net.predict(x)
print("Prediction:", pred)
loss = net.loss(x, t)
print("Loss:", loss)
# Out:
# Prediction: [1.15320003 1.59161743 0.69276279]
# Loss: 1.6177139270586793

# %% [markdown]
# ### 2. 기울기
# 신경망에서의 기울기는 네트워크의 가중치와 편향에 대한 손실 함수의 변화율을 나타내는 벡터입니다. 신경망을 학습시키는 과정에서는 손실 함수의 값을 최소화하기 위해 가중치와 편향을 조절해야 합니다. 이 때, 손실 함수의 기울기를 사용하여 네트워크의 가중치와 편향을 어떻게 조정해야 하는지 결정합니다.

# %%
# 이 함수는 함수 f의 주어진 점 x에서의 수치적 기울기(gradient)를 계산하기 위해 사용됩니다. 
# 수치적 기울기는 각 변수에 대해 매우 작은 값을 더했을 때 함수 값이 얼마나 변하는지를 계산하여 근사합니다. 
# 이 방법은 해석적인 기울기를 구할 수 없는 경우 유용하게 사용됩니다.

def numerical_gradient(f, x):
    h = 1e-4  # 미세한 값 h
    grad = np.zeros_like(x)  # x와 동일한 형상의 배열을 0으로 초기화

    # 모든 인덱스에 대하여 편미분을 수행
    for idx in np.ndindex(x.shape):
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + h
        fxh1 = f(x)  # f(x+h)
        
        x[idx] = tmp_val - h 
        fxh2 = f(x)  # f(x-h)
        grad[idx] = (fxh1 - fxh2) / (2*h)
        
        x[idx] = tmp_val  # 값 복원

    return grad

## 예제 사용
def function_2(x):
    return x[0]**2 + x[1]**2

# 임의의 점에서의 기울기 계산
point = np.array([3.0, 4.0])
grad = numerical_gradient(function_2, point)
print("Gradient at [3.0, 4.0]:", grad)
# Out:
# Gradient at [3.0, 4.0]: [6. 8.]

# %% [markdown]
# ## 2층 신경망 클래스 구현하기
# 2층 신경망 클래스는 입력층, 하나의 은닉층, 그리고 출력층으로 구성된 신경망을 구현하기 위한 프로그램 코드의 구조를 말합니다. 이러한 클래스는 신경망의 구조와 동작을 정의하며, 데이터를 입력받아 처리하고 결과를 출력하는 과정을 담당합니다.

# %%
# ChatGPT
# 1. 두층 신경망 클래스 구현
import numpy as np

class TwoLayerNet:
    def __init__(self, input_size, hidden_size, output_size, weight_init_std=0.01):
        # 가중치 초기화
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)

    def predict(self, x):
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']

        a1 = np.dot(x, W1) + b1
        z1 = sigmoid(a1)
        a2 = np.dot(z1, W2) + b2
        predicty = softmax(a2)
        
        return y

    def loss(self, x, t):
        y = self.predict(x)
        return cross_entropy_error(y, t)

    def accuracy(self, x, t):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        t = np.argmax(t, axis=1)
        
        accuracy = np.sum(y == t) / float(x.shape[0])
        return accuracy

    def numerical_gradient(self, x, t):
        loss_W = lambda W: self.loss(x, t)

        grads = {}
        grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
        grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
        grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
        grads['b2'] = numerical_gradient(loss_W, self.params['b2'])

        return grads

    
# 2. 손실함수 및 활성화 함수 정리
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def softmax(x):
    if x.ndim == 2:
        x = x - x.max(axis=1, keepdims=True)
        x = np.exp(x)
        x /= x.sum(axis=1, keepdims=True)
    elif x.ndim == 1:
        x = x - np.max(x)
        x = np.exp(x) / np.sum(np.exp(x))
    return x

def cross_entropy_error(y, t):
    if y.ndim == 1:
        t = t.reshape(1, t.size)
        y = y.reshape(1, y.size)
    delta = 1e-7
    return -np.sum(t * np.log(y + delta)) / y.shape[0]


# 3. 미니배치 학습 구현
from tensorflow.keras.datasets import mnist

# 데이터 로드
(x_train, t_train), (x_test, t_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], -1) / 255.0
x_test = x_test.reshape(x_test.shape[0], -1) / 255.0
t_train = np.eye(10)[t_train]  # 원-핫 인코딩

# 하이퍼파라미터
iters_num = 10000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

network = TwoLayerNet(input_size=784, hidden_size=50, output_size=10)

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    # 기울기 계산
    grad = network.numerical_gradient(x_batch, t_batch)
    
    # 매개변수 갱신
    for key in ('W1', 'b1', 'W2', 'b2'):
        network.params[key] -= learning_rate * grad[key]
    
    # 학습 경과 기록
    loss = network.loss(x_batch, t_batch)
    if i % 1000 == 0:
        print(f"Iteration {i}, Loss: {loss}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[445], line 94
#      91 t_batch = t_train[batch_mask]
#      93 # 기울기 계산
# ---> 94 grad = network.numerical_gradient(x_batch, t_batch)
#      96 # 매개변수 갱신
#      97 for key in ('W1', 'b1', 'W2', 'b2'):
#
# Cell In[445], line 41, in TwoLayerNet.numerical_gradient(self, x, t)
#      38 loss_W = lambda W: self.loss(x, t)
#      40 grads = {}
# ---> 41 grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
#      42 grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
#      43 grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
#
# Cell In[416], line 9, in numerical_gradient(f, x)
#       7 tmp_val = x[idx]
#       8 x[idx] = float(tmp_val) + h
# ----> 9 fxh1 = f(x)  # f(x+h)
#      11 x[idx] = tmp_val - h
#      12 fxh2 = f(x)  # f(x-h)
#
# ...

# %%
# 강사방법
class TwoLayerNet:
    def __init__(self, input_size, hidden_size, output_size):
        I, H, O = input_size, hidden_size, output_size
        self.params = {}
        self.params['w1'] = np.random.randn(I,H)
        self.params['b1'] = np.random.randn(H)
        self.params['w2'] = np.random.randn(H, O)
        self.params['b2'] = np.random.randn(O)
        
    def predict(self, x):
        w1, w2 = self.params['w1'], self.params['w2']
        b1, b2 = self.params['b1'], self.params['b2']
        
        a1 = np.dot(x,w1) + b1
        z1 = sigmoid(a1)
        a2 = np.dot(z1, w2) + b2
        y = softmax(a2)
        
        return y
    
    def loss(self, x, t):
        y = self.predict(x)
        return cross_entropy_error(y, t)
    
    def accuracy(self, x, t):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        t = np.argmax(t, axis=1)
        
        accuracy = np.sum(y == t) / len(x)
        return accuracy
    
    def numerical_gradient(self, x, t):
        loss_W = lambda W: self.loss(x, t)

        grads = {}
        grads['w1'] = numerical_gradient(loss_W, self.params['w1'])
        grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
        grads['w2'] = numerical_gradient(loss_W, self.params['w2'])
        grads['b2'] = numerical_gradient(loss_W, self.params['b2'])

        return grads

# %%
#ChatGPT
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# Iris 데이터 로드
iris = load_iris()
x = iris.data
y = iris.target.reshape(-1, 1)  # target을 열 벡터로 변환

# 타겟 데이터 원-핫 인코딩
encoder = OneHotEncoder(sparse=False)
y_onehot = encoder.fit_transform(y)

# 데이터 분할
train_x, test_x, train_y, test_y = train_test_split(x, y_onehot, test_size=0.2, random_state=42)

# 신경망 인스턴스 생성
network = TwoLayerNet(input_size=4, hidden_size=50, output_size=3)

# 훈련 파라미터 설정
learning_rate = 0.1
epochs = 500

# 훈련 과정
for epoch in range(epochs):
    # 예측 및 손실 계산
    loss = network.loss(train_x, train_y)
    
    # 기울기 계산
    grads = network.numerical_gradient(train_x, train_y)
    
    # 매개변수 업데이트
    for key in ('W1', 'b1', 'W2', 'b2'):
        network.params[key] -= learning_rate * grads[key]

    # 로깅
    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Loss: {loss:.4f}")

# 테스트 데이터셋을 사용한 모델 평가
test_loss = network.loss(test_x, test_y)
test_accuracy = network.accuracy(test_x, test_y)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 0, Loss: 1.0982
# Epoch 50, Loss: 1.0879
# Epoch 100, Loss: 0.9928
# Epoch 150, Loss: 0.7255
# Epoch 200, Loss: 0.5332
# Epoch 250, Loss: 0.4416
# Epoch 300, Loss: 0.3815
# Epoch 350, Loss: 0.3324
# Epoch 400, Loss: 0.2902
# Epoch 450, Loss: 0.2544
# Test Loss: 0.2321, Test Accuracy: 1.0000

# %%
#강사 방법
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# Iris 데이터 로드
iris = load_iris()
x = iris.data
y = iris.target


# 데이터 분할
train_x, test_x, train_y, test_y = train_test_split(x, y)


# 신경망 인스턴스 생성
net = TwoLayerNet(input_size=4, hidden_size=8, output_size=3)

loss_box = []
learning_rate = 0.1 

for i in range(3000):
    grad = net.numerical_gradient(train_x, train_y)
    for key in ('w1', 'b1', 'w2', 'b2'):
        net.params[key] -= grad[key] * learning_rate
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[449], line 22
#      19 learning_rate = 0.1
#      21 for i in range(3000):
# ---> 22     grad = net.numerical_gradient(train_x, train_y)
#      23     for key in ('w1', 'b1', 'w2', 'b2'):
#      24         net.params[key] -= grad[key] * learning_rate
#
# Cell In[447], line 38, in TwoLayerNet.numerical_gradient(self, x, t)
#      35 loss_W = lambda W: self.loss(x, t)
#      37 grads = {}
# ---> 38 grads['w1'] = numerical_gradient(loss_W, self.params['w1'])
#      39 grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
#      40 grads['w2'] = numerical_gradient(loss_W, self.params['w2'])
#
# Cell In[416], line 9, in numerical_gradient(f, x)
#       7 tmp_val = x[idx]
#       8 x[idx] = float(tmp_val) + h
# ----> 9 fxh1 = f(x)  # f(x+h)
#      11 x[idx] = tmp_val - h
#      12 fxh2 = f(x)  # f(x-h)
#
# ...

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# 활성화 함수와 손실 함수
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def softmax(x):
    if x.ndim == 2:
        x = x - x.max(axis=1, keepdims=True)
        x = np.exp(x)
        x /= x.sum(axis=1, keepdims=True)
    elif x.ndim == 1:
        x = x - np.max(x)
        x = np.exp(x) / np.sum(np.exp(x))
    return x

def cross_entropy_error(y, t):
    if y.ndim == 1:
        y = y.reshape(1, -1)
        t = t.reshape(1, -1)
    delta = 1e-7
    return -np.sum(t * np.log(y + delta)) / y.shape[0]

def numerical_gradient(f, x):
    h = 1e-4
    grad = np.zeros_like(x)

    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:
        idx = it.multi_index
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + h
        fxh1 = f(x)  # f(x+h)

        x[idx] = tmp_val - h
        fxh2 = f(x)  # f(x-h)
        grad[idx] = (fxh1 - fxh2) / (2 * h)

        x[idx] = tmp_val
        it.iternext()

    return grad

# Iris 데이터 로드 및 전처리
iris = load_iris()
x = iris.data
y = iris.target

# 데이터 분할
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.3, random_state=42)

# 타겟 원-핫 인코딩
encoder = OneHotEncoder(sparse=False, categories='auto')
train_y = encoder.fit_transform(train_y.reshape(-1, 1))
test_y = encoder.transform(test_y.reshape(-1, 1))

# 신경망 인스턴스 생성
net = TwoLayerNet(input_size=4, hidden_size=8, output_size=3)

# 학습
loss_box, test_loss_box = [], []
learning_rate = 0.1
epochs = 3000

for i in range(epochs):
    grad = net.numerical_gradient(train_x, train_y)
    for key in ('w1', 'b1', 'w2', 'b2'):
        net.params[key] -= learning_rate * grad[key]

    loss = net.loss(train_x, train_y)
    test_loss = net.loss(test_x, test_y)
    loss_box.append(loss)
    test_loss_box.append(test_loss)

    if i % 100 == 0:
        print(f"Iteration {i}: Loss {loss:.4f}, Test Loss {test_loss:.4f}")

plt.plot(loss_box, label='Train Loss')
plt.plot(test_loss_box, label='Test Loss')
plt.title('Training and Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Iteration 0: Loss 1.3242, Test Loss 1.4483
# Iteration 100: Loss 0.4778, Test Loss 0.4169
# Iteration 200: Loss 0.3780, Test Loss 0.3258
# Iteration 300: Loss 0.3057, Test Loss 0.2610
# Iteration 400: Loss 0.2532, Test Loss 0.2138
# Iteration 500: Loss 0.2155, Test Loss 0.1795
# Iteration 600: Loss 0.1879, Test Loss 0.1543
# Iteration 700: Loss 0.1670, Test Loss 0.1351
# Iteration 800: Loss 0.1509, Test Loss 0.1201
# Iteration 900: Loss 0.1381, Test Loss 0.1078
# Iteration 1000: Loss 0.1273, Test Loss 0.0973
# Iteration 1100: Loss 0.1188, Test Loss 0.0891
# Iteration 1200: Loss 0.1123, Test Loss 0.0830
# Iteration 1300: Loss 0.1071, Test Loss 0.0781
# Iteration 1400: Loss 0.1028, Test Loss 0.0742
# ...

# %%
pred = net.predict(test_x)
pred = np.argmax(pred, axis=1) 
pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0])

# %%
# 라이브러리(딥러닝)
from tensorflow import keras
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

iris = load_iris()

x = iris.data
y = iris.target

# 데이터 분할
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.3, random_state=42)

ss = StandardScaler()
train_scaled = ss.fit_transform(train_x)
test_scaled = ss.fit_transform(test_x)

model = keras.Sequential() # 인공신경망을 설계하기 위한 도화지
model.add(keras.layers.Dense(8, activation='relu', input_shape=(4,)))
model.add(keras.layers.Dense(8, activation='relu'))
model.add(keras.layers.Dense(3, activation='softmax'))
model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer='adam',
             metrics = ['accuracy'])

# 조기 종료 콜백 추가
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=50)  # 50 에포크 동안 개선이 없으면 종료

hist = model.fit(train_scaled, train_y, epochs=1000, 
          validation_data=(test_scaled, test_y), callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3042 - loss: 1.1421 - val_accuracy: 0.3778 - val_loss: 1.0966
# Epoch 2/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3115 - loss: 1.1368 - val_accuracy: 0.4222 - val_loss: 1.0719
# Epoch 3/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3094 - loss: 1.1395 - val_accuracy: 0.4444 - val_loss: 1.0482
# Epoch 4/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3833 - loss: 1.0752 - val_accuracy: 0.4889 - val_loss: 1.0260
# Epoch 5/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4155 - loss: 1.0765 - val_accuracy: 0.4889 - val_loss: 1.0044
# ...

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# ### 1. 미니배치 학습
# 미니배치 학습은 기계학습에서 사용되는 훈련 방법 중 하나입니다. 전체 데이터 세트를 한 번에 사용하여 모델을 학습시키는 대신, 데이터 세트를 작은 배치(batch)로 나누어 각 배치에 대해 학습을 수행하는 방식을 말합니다. 이 때 각각의 작은 배치를 미니배치(mini-batch)라고 합니다.

# %% [markdown]
# ### 2. 모델 평가
# 딥러닝에서 평가는 학습된 모델이 얼마나 잘 작동하는지를 측정하는 과정입니다. 이 과정에서는 특정 지표(metric)를 사용하여 모델의 예측 성능을 평가하게 됩니다.

# %%
# ChatGPT가 만들어주는 CNN
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.datasets import fashion_mnist

# 데이터 로드
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255

# 라벨을 원-핫 인코딩
train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    BatchNormalization(),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    BatchNormalization(),
    
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    BatchNormalization(),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
history = model.fit(train_images, train_labels, epochs=10, validation_split=0.2)
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
#!pip3 install tensorflow --timeout=1000
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# 데이터셋을 불러오고 훈련/테스트 세트로 나눕니다.
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),  # 28x28 이미지를 1D 벡터로 변환
    tf.keras.layers.Dense(128, activation='relu'),  # 128개의 노드를 가진 은닉층
    tf.keras.layers.Dropout(0.2),  # 과적합 방지를 위한 드롭아웃
    tf.keras.layers.Dense(10, activation='softmax')  # 10개의 출력 노드, 각 숫자의 확률 출력
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size = 64)
# 모델 훈련 부분에서 batch_size=64를 설정함으로써, 60000개의 훈련 샘플을 64개씩의 배치로 나누어 훈련시킵니다. 이는 한 번에 64개의 이미지만 메모리에 로드되어 처리된다는 의미입니다.

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8359 - loss: 0.5677
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9483 - loss: 0.1781
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9624 - loss: 0.1271
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9703 - loss: 0.0982
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9742 - loss: 0.0838
# 313/313 - 0s - 878us/step - accuracy: 0.9756 - loss: 0.0788
#
# Test accuracy: 0.975600004196167

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 데이터 불러오기 및 전처리
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255
train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# 데이터 증강
train_datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=False,
    fill_mode='nearest'
)

# 모델 구성
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    Flatten(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련
model.fit(train_datagen.flow(train_images, train_labels, batch_size=64),
          steps_per_epoch=int(len(train_images) / 64),  # float을 int로 변환
          epochs=10, validation_data=(test_images, test_labels))

# 모델 평가
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest accuracy:', test_acc)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold

# 데이터 로드
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 데이터 전처리
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255

# 라벨 원-핫 인코딩
train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# 데이터 증강
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=False,
    fill_mode='nearest'
)

def build_model():
    model = Sequential([
        Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(28, 28, 1)),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax')
    ])
    return model

# 교차 검증 설정
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# 교차 검증 수행
fold_no = 1
for train, val in kfold.split(train_images, train_labels):
    # 모델 생성
    model = build_model()
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    # 훈련 데이터 준비
    train_gen = datagen.flow(train_images[train], train_labels[train], batch_size=64)
    val_gen = datagen.flow(train_images[val], train_labels[val], batch_size=64)
    
    # 모델 훈련
    print(f'Training for fold {fold_no}...')
    model.fit(train_gen, epochs=10, validation_data=val_gen)
    
    fold_no += 1

# 최종 모델 평가
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('\nTest accuracy:', test_acc)
